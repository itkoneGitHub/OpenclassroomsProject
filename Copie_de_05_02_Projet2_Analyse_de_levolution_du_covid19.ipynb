# %% [markdown]
# <a href="https://colab.research.google.com/github/itkoneGitHub/OpenclassroomsProject/blob/cagnotte/Copie_de_05_02_Projet2_Analyse_de_levolution_du_covid19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dans ce projet, nous allons analyser l'évolution du Covid 19 dans le monde
# Source des données: https://www.ecdc.europa.eu/en/publications-data/download-todays-data-geographic-distribution-covid-19-cases-worldwide

# %% [markdown]
# Voici quelques questions qui peuvent guider notre analyse
# * Quels sont les pays avec les plus grand nombres de cas ?
# * Quels sont les pays avec un taux de mortalité élevé ?
# * Le confinement a-t-il eu un effet sur le nombre de cas ?
# * Comparer la situation par continent

# %% [markdown]
# # Importer les données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install xlrd==1.2.0
# Out:
# Requirement already satisfied: xlrd==1.2.0 in /usr/local/lib/python3.11/dist-packages (1.2.0)

# %%
df=pd.read_excel('https://github.com/kevindegila/data-analyst/blob/main/datasets/COVID-19-geographic-disbtribution-worldwide-2020-12-14.xls')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-fda4913f6418> in <cell line: 0>()
# ----> 1 df=pd.read_excel('https://github.com/kevindegila/data-analyst/blob/main/datasets/COVID-19-geographic-disbtribution-worldwide-2020-12-14.xls')
#       2 df.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1552                 )
#    1553                 if ext is None:
# -> 1554                     raise ValueError(
#    1555                         "Excel file format cannot be determined, you must specify "
#    1556                         "an engine manually."
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
# prompt: df=pd.read_excel('https://github.com/kevindegila/data-analyst/blob/main/datasets/COVID-19-geographic-disbtribution-worldwide-2020-12-14.xls')
# df.head() ValueError                                Traceback (most recent call last)
# <ipython-input-11-fda4913f6418> in <cell line: 0>()
# ----> 1 df=pd.read_excel('https://github.com/kevindegila/data-analyst/blob/main/datasets/COVID-19-geographic-disbtribution-worldwide-2020-12-14.xls')
#       2 df.head()
# 1 frames
# /usr/local/lib/python3.11/dist-packages/pandas/io/excel/_base.py in __init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1552                 )
#    1553                 if ext is None:
# -> 1554                     raise ValueError(
#    1555                         "Excel file format cannot be determined, you must specify "
#    1556                         "an engine manually."
# ValueError: Excel file format cannot be determined, you must specify an engine manually. resolves issues

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Direct link to the raw file content on GitHub
url = 'https://raw.githubusercontent.com/kevindegila/data-analyst/main/datasets/COVID-19-geographic-disbtribution-worldwide-2020-12-14.xls'

# Read the Excel file using pandas
df = pd.read_excel(url)

df.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# 2                                           6.868768
# 3                                           7.134266
# 4                                           6.968658

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
#  7   geoId                                                       61625 non-null  object
#  8   countryterritoryCode                                        61777 non-null  object
#  9   popData2019                                                 61777 non-null  float64
#  10  continentExp                                                61900 non-null  object
#  11  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  59021 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 5.7+ MB

# %%
df.describe()
# Out:
#                 day         month          year          cases        deaths  \
# count  61900.000000  61900.000000  61900.000000   61900.000000  61900.000000
# mean      15.628934      7.067157   2019.998918    1155.147237     26.055460
# std        8.841582      2.954776      0.032882    6779.224479    131.227055
# min        1.000000      1.000000   2019.000000   -8261.000000  -1918.000000
# 25%        8.000000      5.000000   2020.000000       0.000000      0.000000
# 50%       15.000000      7.000000   2020.000000      15.000000      0.000000
# 75%       23.000000     10.000000   2020.000000     273.000000      4.000000
# max       31.000000     12.000000   2020.000000  234633.000000   4928.000000
#
#         popData2019  \
# count  6.177700e+04
# mean   4.098770e+07
# std    1.531294e+08
# min    8.150000e+02
# 25%    1.293120e+06
# 50%    7.169456e+06
# 75%    2.851583e+07
# max    1.433784e+09
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# count                                       59021.000000
# mean                                           66.320586
# std                                           162.329240
# min                                          -147.419587
# 25%                                             0.757526
# 50%                                             6.724045
# 75%                                            52.572719
# max                                          1900.836210

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
# Calculating the percentage of null values:
# CODE:
df.isna().sum().sum()/len(df)
# Out:
# 0.05492730210016155

# %%
# Supprimr les valeurs nulles
df.dropna(inplace=True)

# %% [markdown]
# # Pays avec les plus grand nombres de cas

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
df_by_country=df.groupby('countriesAndTerritories')[['cases', 'deaths']].sum().sort_values('cases',ascending=False)
df_by_country
# Out:
#                                 cases  deaths
# countriesAndTerritories
# United_States_of_America     16256754  299177
# India                         9884100  143355
# Brazil                        6901952  181402
# Russia                        2653928   46941
# France                        2376852   57911
# ...                               ...     ...
# Montserrat                          8       1
# Falkland_Islands_(Malvinas)         8       0
# Anguilla                            7       0
# Marshall_Islands                    3       0
# Vanuatu                             0       0
#
# [211 rows x 2 columns]

# %% [markdown]
# # Pays avec Taux de mortalité élevé

# %%
df_by_country['mortality_rate']=df_by_country['deaths']/df_by_country['cases']
df_by_country.sort_values('mortality_rate',ascending=False)
# Out:
#                                     cases  deaths  mortality_rate
# countriesAndTerritories
# Yemen                                2082     606        0.291066
# Montserrat                              8       1        0.125000
# Mexico                            1250044  113953        0.091159
# Isle_of_Man                           305      25        0.081967
# Ecuador                            202110   13875        0.068651
# ...                                   ...     ...             ...
# Eritrea                               689       0        0.000000
# Saint_Vincent_and_the_Grenadines       91       0        0.000000
# Northern_Mariana_Islands              102       0        0.000000
# Marshall_Islands                        3       0        0.000000
# Vanuatu                                 0       0             NaN
#
# [211 rows x 3 columns]

# %%
#Sorting the values for the mortality rate in the descending order
plt.figure(figsize=(15,10))
ax = df_by_country['mortality_rate'].sort_values(ascending=False).head(20).plot.bar()
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.set_xlabel("Country")
ax.set_ylabel("Mortality rate")
ax.set_title("Countries with highest mortality rates")
# Out:
# Text(0.5, 1.0, 'Countries with highest mortality rates')

# %% [markdown]
# # Pays avec le plus de morts

# %%
df_by_country.sort_values('deaths',ascending=False)
# Out:
#                              cases  deaths  mortality_rate
# countriesAndTerritories
# United_States_of_America  16256754  299177        0.018403
# Brazil                     6901952  181402        0.026283
# India                      9884100  143355        0.014504
# Mexico                     1250044  113953        0.091159
# Italy                      1843712   64520        0.034995
# ...                            ...     ...             ...
# Eritrea                        689       0        0.000000
# Seychelles                     180       0        0.000000
# Faroe_Islands                  510       0        0.000000
# Mongolia                       901       0        0.000000
# Vanuatu                          0       0             NaN
#
# [211 rows x 3 columns]

# %%
#sorting the number of deaths in the descending order
plt.figure(figsize=(10,6))
ax=df_by_country['deaths'].sort_values(ascending=False).head(5).plot(kind='bar')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title("Countries suffering the most fatalities from COVID-19")
ax.set_xlabel("Countries")
ax.set_ylabel("Number of deaths")
# Out:
# Text(0, 0.5, 'Number of deaths')

# %% [markdown]
# # Effet du confinement sur le nombre de cas

# %%
df_by_month = df.groupby('month')[['cases','deaths']].sum()

# %%
df_by_month.head()
# Out:
#          cases  deaths
# month
# 1         9767     212
# 2        74717    2702
# 3       714475   35668
# 4      2338739  189142
# 5      2891247  140118

# %%
fig=plt.figure(figsize=(15,10))
ax1=fig.add_subplot(1,2,1)
ax2=fig.add_subplot(1,2,2)

df_by_month['cases'].plot(kind='line',ax=ax1)
ax1.set_title("Nombre total de cas de covid par mois")
ax1.set_xlabel("Mois")
ax1.set_ylabel("Nombre de cas")
df_by_month['deaths'].plot(kind='line',ax=ax2)
ax2.set_title("Nombre total de morts par mois")
ax2.set_xlabel("Mois")
ax2.set_ylabel("Nombre de morts")
# Out:
# Text(0, 0.5, 'Nombre de morts')

# %% [markdown]
# Quand on regarde de façon globale on a pas l'impression d'une diminution. Essayons de voir le cas de certains pays en particulier, qui ont un confinement strict

# %%
df_germany = df[df.countriesAndTerritories == 'Germany']
df_germany_monthwise = df_germany.groupby('month')[['cases','deaths']].sum()
df_germany_grouped = df_germany_monthwise.reset_index()


df_uk = df[df.countriesAndTerritories == 'United_Kingdom']
df_uk_monthwise = df_uk.groupby('month')[['cases','deaths']].sum()
df_uk_grouped = df_uk_monthwise.reset_index()


df_france = df[df.countriesAndTerritories == 'France']
df_france_monthwise = df_france.groupby('month')[['cases','deaths']].sum()
df_france_grouped = df_france_monthwise.reset_index()


df_italy = df[df.countriesAndTerritories == 'Italy']
df_italy_monthwise = df_italy.groupby('month')[['cases','deaths']].sum()
df_italy_grouped = df_italy_monthwise.reset_index()

# %%
fig=plt.figure(figsize=(20,15))

ax1=fig.add_subplot(2,2,1)
df_uk_grouped.plot(kind='line',x='month',y='cases',ax=ax1)
ax1.set_title("Evolution du covid en UK")

ax2=fig.add_subplot(2,2,2)
df_france_grouped.plot(kind='line',x='month',y='cases',ax=ax2)
ax2.set_title("Evolution du covid en France")

ax3=fig.add_subplot(2,2,3)
df_italy_grouped.plot(kind='line',x='month',y='cases',ax=ax3)
ax3.set_title("Evolution du covid en Italy")

ax4=fig.add_subplot(2,2,4)
df_germany_grouped.plot(kind='line',x='month',y='cases',ax=ax4)
ax4.set_title("Evolution du covid en Allemagne")
plt.show()

# %% [markdown]
# # Situation par continent ?

# %%
df.columns
# Out:
# Index(['dateRep', 'day', 'month', 'year', 'cases', 'deaths',
#        'countriesAndTerritories', 'geoId', 'countryterritoryCode',
#        'popData2019', 'continentExp',
#        'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000'],
#       dtype='object')

# %%
df['continentExp'].value_counts()
# Out:
# continentExp
# Europe     16657
# Africa     14004
# America    13105
# Asia       12695
# Oceania     2298
# Name: count, dtype: int64

# %%
df.groupby('continentExp')[['cases', 'deaths']].sum().sort_values('cases', ascending=False)
# Out:
#                  cases  deaths
# continentExp
# America       30884895  785370
# Europe        21395058  479706
# Asia          16780431  290097
# Africa         2361775   56134
# Oceania          53298    1151

# %%
df.groupby('continentExp')[['cases', 'deaths']].sum().sort_values('deaths', ascending=False)
# Out:
#                  cases  deaths
# continentExp
# America       30884895  785370
# Europe        21395058  479706
# Asia          16780431  290097
# Africa         2361775   56134
# Oceania          53298    1151
